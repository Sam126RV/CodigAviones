# %% [markdown]
# ### "Actividad M2.1 Uso de Google Colab

# %% [markdown]
# ## Actividad Git-GitHub Equipo 2

# %% [markdown]
# Miembros del Equipo:
#
# - Samantha Ruelas Valtierra
# - Gadiel Gerardo Wisar Sotelo
# - María Fernanda Lee Ponce
# - Luis Alejo Muñoz Ledo
# - Julio Eugenio Guevara Galván
# - Daniela Márquez Campos
# - David Fernando Arméndariz Torres

# %% [markdown]
# Tecnológico de Monterrey

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# En esta parte se hace una lectura del archivo .csv donde se encuentra la  base de datos del colestero y se almacena en la variable df

# %%
df = pd.read_csv('/content/gdrive/MyDrive/TC2004B/titanic.csv')

# %%
display(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##**Descripción de Variables**

# %% [markdown]
# ####1. Identifica el tipo de variables presentes en el dataset, y en una celda describe cuáles variables son categóricas y cuáles numéricas. Muestra esta información en forma de lista

# %% [markdown]
# Las variables de esta base de datos son las siguientes
#
# 1.   PassengerId
# 2.   Survived
# 3. Pclass
# 4. Name
# 5. Sex
# 6. Age
# 7. SibSp
# 8. Parch
# 9. Ticket
# 10. Fare
# 11. Cabin
# 12. Embarked

# %% [markdown]
# # **Variables numéricas**
#
#
#
# 1.   PassengerId
# 2.   Survived
# 3. Pclass
# 4. Age
# 5. SibSP
# 6. Parch
#
#
# # **Variables categóricas**
# 1. Name
# 2. Sex
# 3. Ticket
# 4. Cabin
# 5. Embarked

# %% [markdown]
# ####2. Utiliza en diferentes celdas de código las funciones columns(), info() y describe() del dataframe. Muestra la información generada.

# %%
display(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 3. Explica que hace cada una de estas funciones.

# %% [markdown]
# Lo que se hacecolumns()  es acceder al atributo de df de columns y muestra en un arreglo todo el indice de los nombres de cada una de ellas.

# %% [markdown]
# el método info() nos proporciona la cantidad de filas y columnas, dandonos tambien el nombre de cada columna, nos da tambien la cantidad de valores no nuloss y el tipo de datos de cada columna

# %% [markdown]
# El método describe nos devuelve estadísticas descriptivas como
#
#
# 1.  la media
# 2.  mediana
# 3. valor minimo
# 4. valor maximo
# 5. desviación estandar

# %% [markdown]
# # 4. Indica cuántos registros se tienen en total, cuáles tienen valores nulos y cuáles no tienen valores nulos.

# %% [markdown]
# > Para saber cuantos registros se tienen en total en nuestra base de datos, podemos utilizar la función len() que nos dara a conocer el total de las filas

# %%
display(len(df))
# Out:
# 891

# %% [markdown]
# Para conocer cuales tienen valores nulos y no, podemos usar los metodos isnull() y .notnull()

# %%
display("con valores nulos", df.isnull().sum())
display("sin valores nulos", df.notnull().sum())
# Out:
# 'con valores nulos'
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# 'sin valores nulos'
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %% [markdown]
# ## 5. ¿Qué columnas aparecen en el resultado de describe? ¿Cuál es la tarifa más cara? ¿Cuál es el promedio de edad?

# %%
las columnas quee aparecen en describe son count, mean, std, min, 25%, 50%, 75% y max

# %% [markdown]
# La tarifa mas cara podemos obtenerla ejecutando el metodo max() en la base de datos seleccionando la columna Fare

# %%
max_tarifa= df["Fare"].max()

display(max_tarifa)
# Out:
# 512.3292

# %% [markdown]
# El promedio de las edades se usaria casi lo mismo a excecion que algina usaremos el metodo mean()

# %%
prom_edad= df['Age'].mean()
print("El promedio de edad es:", prom_edad)
# Out:
# El promedio de edad es: 29.69911764705882

# %% [markdown]
# #### 6. Escribe el código necesario para indicar de las variables categóricas  cuantos valores diferentes se tiene por categoría. Puedes usar el método unique() para regresar los valores únicos de una columna.

# %%
total__columnas = df.select_dtypes(include=['object']).columns

for col in total__columnas:
    display(len(df[col].unique()))
# Out:
# 891
# 2
# 681
# 148
# 4

# %% [markdown]
# # Agrega encabezado "Análisis de Datos"

# %% [markdown]
# 7. Agrega el código para indicar cuánto es el total que se pagó sumando la tarifa de todos los pasajeros.

# %%
pagoTotal = df["Fare"].sum()
display(pagoTotal)
# Out:
# 28693.9493

# %% [markdown]
# 8. Crea un subconjunto de los datos de los que sobrevivieron y otro de los que no sobrevivieron usando df[condición]

# %%
sobrevivientes = df[df["Survived"] == 1]
display(sobrevivientes)

noSobrevivientes = df[df["Survived"] == 0]
display(noSobrevivientes)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 9. Mostrar los datos de 5 personas de las que sobrevivieron y de las que no sobrevivieron.

# %%
#head es el metodo que nos permite conocer de las columnas los valores de las filas 
vivos = df[df["Survived"] == 1].head(5)
display(vivos)

muertos = df[df["Survived"] == 0].head(5)
display(muertos)
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C
# ...

# %% [markdown]
# Este es el cambio hecho en colab por Sam
